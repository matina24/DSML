# %%
number = 56.33

if isinstance(number, int):
    print(f"Square root= {number ** 0.5} ")
else:
    raise TypeError(f"Value should be int, not {type(number)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 if isinstance(number, int):
#       4     print(f"Square root= {number ** 0.5} ")
#       5 else:
# ----> 6     raise TypeError(f"Value should be int, not {type(number)}")
#       7
#
# TypeError: Value should be int, not <class 'float'>

# %%
def divide(x,y):
    if y == 0:
        raise ValueError("Divisor must not be zero")

    return x/y

divide(6,0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       3         raise ValueError("Divisor must not be zero")
#       4
#       5     return x/y
#       6
# ----> 7 divide(6,0)
#
# Cell In[3], line 3, in divide(x, y)
#       1 def divide(x,y):
#       2     if y == 0:
# ----> 3         raise ValueError("Divisor must not be zero")
#       4
#       5     return x/y
#
# ValueError: Divisor must not be zero

# %% [markdown]
# user defined exception

# %%
class InvalidAgeException:
    """
    Raise when input age is less than 18
    """
    pass

raise InvalidAgeException()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       3     Raise when input age is less than 18
#       4     """
#       5     pass
#       6
# ----> 7 raise InvalidAgeException()
#
# TypeError: exceptions must derive from BaseException

# %%
def check_customer(customer_id):

    age =15
    if "liquior":
        if age >= 18:
            print("okay")
        else:
            raise InvalidAgeException("Must be an adult to buy liquior, age >18")


check_customer(9856)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 11
#       7         else:
#       8             raise InvalidAgeException("Must be an adult to buy liquior, age >18")
#       9
#      10
# ---> 11 check_customer(9856)
#
# Cell In[7], line 8, in check_customer(customer_id)
#       4     if "liquior":
#       5         if age >= 18:
#       6             print("okay")
#       7         else:
# ----> 8             raise InvalidAgeException("Must be an adult to buy liquior, age >18")
#
# TypeError: InvalidAgeException() takes no arguments

# %%
class InvalidAmountException:
    """
    Raise when input amount is less than 3000
    """
    pass

# %%
def get_cash(withdraw_amount):
    total_amount = 2500

    if "withdraw":
        
        if withdraw_amount <= total_amount:
            raise InvalidAmountException("Your account has insufficient balance")

        


get_cash(3500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 11
#       7             print("Take your withdrawal money below")
#       8         else:
#       9             raise InvalidAmountException("Your account has insufficient balance")
#      10
# ---> 11 get_cash(3500)
#
# Cell In[18], line 9, in get_cash(withdraw_amount)
#       5
#       6         if withdraw_amount <= total_amount:
#       7             print("Take your withdrawal money below")
#       8         else:
# ----> 9             raise InvalidAmountException("Your account has insufficient balance")
#
# TypeError: InvalidAmountException() takes no arguments

# %%
class InsufficientBalanceException(Exception):
    """Custom exception for insufficient balance."""
    pass
 
 
def withdraw_balance(amount):
    balance = 2500
 
    if amount > balance:
        raise InsufficientBalanceException("Not sufficient balance")
 
    return f"Remaining balance: {balance - amount}"
 
 
print(withdraw_balance(7000))
# Out:
# ---------------------------------------------------------------------------
# InsufficientBalanceException              Traceback (most recent call last)
# Cell In[14], line 15
#      11
#      12     return f"Remaining balance: {balance - amount}"
#      13
#      14
# ---> 15 print(withdraw_balance(7000))
#
# Cell In[14], line 10, in withdraw_balance(amount)
#       6 def withdraw_balance(amount):
#       7     balance = 2500
#       8
#       9     if amount > balance:
# ---> 10         raise InsufficientBalanceException("Not sufficient balance")
#      11
#      12     return f"Remaining balance: {balance - amount}"
#
# InsufficientBalanceException: Not sufficient balance

# %%
# diff betn raise, raise valueerror, raise valueerror("Invalid value")
