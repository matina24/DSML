# %%
name="Christina"
type(name)
# Out:
# str

# %%
number="123"
type(number)
# Out:
# str

# %%
int(number)
type(int(number)    )
# Out:
# int

# %%
address=str("kathmandu, Nepal")
address
# Out:
# 'kathmandu, Nepal'

# %%
x=("hello. everyone")
x.upper()
# Out:
# 'HELLO. EVERYONE'

# %%
x.lower()
# Out:
# 'hello. everyone'

# %%
x.strip()
# Out:
# 'hello. everyone'

# %%
x.strip("h")
# Out:
# 'ello. everyone'

# %%
x.replace("hello", "hi" )
# Out:
# 'hi. everyone'

# %%
x.split(".")
# Out:
# ['hello', ' everyone']

# %%
x.split("e")
# Out:
# ['h', 'llo. ', 'v', 'ryon', '']

# %%
email="student@info.com"
if email.endswith("@gmail.com"):
    print("Valid Gmail address")
else:
    print("Not a Gmail address")
# Out:
# Not a Gmail address

# %%
"tisa" + "Shakya"
# Out:
# 'tisaShakya'

# %%
x="ram"

# %%
x.capitalize()
# Out:
# 'Ram'

# %%
"-".join(["apple", "banana", "cherry"])
# Out:
# 'apple-banana-cherry'

# %%
"-" * 100
# Out:
# '----------------------------------------------------------------------------------------------------'

# %%
address="kathmandu, Nepal"
address[0]
address[0:9]
# Out:
# 'kathmandu'

# %%
len(address)
# Out:
# 16

# %%
address[-1]
# Out:
# 'l'

# %%
address
# Out:
# 'kathmandu, Nepal'

# %%
address[1:-1:3]
# Out:
# 'amd p'

# %%
address[::2]
# Out:
# 'ktmnu ea'

# %%
text="madam"        #palindrome
text[::-1 ]
# Out:
# 'madam'

# %%
name="tisa"
age=23
sent="your name is {} and your age is {}".format(name.capitalize(), age)
sent
# Out:
# 'your name is Tisa and your age is 23'

# %%
sent= f"your name is {name.capitalize()} and your age is {age}"
sent
# Out:
# 'your name is Tisa and your age is 23'

# %%
long_string = """This is a long string that spans multiple lines.
It can be useful for writing documentation or 
including large blocks of text in your code.  """

# %%
print(long_string)
# Out:
# This is a long string that spans multiple lines.
# It can be useful for writing documentation or
# including large blocks of text in your code.
