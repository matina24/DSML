# %%
number = 1234

# %%
type(number)
# Out:
# int

# %%
print(number)
# Out:
# 1234

# %%
num=1.234
type(num)
print(num)
# Out:
# 1.234

# %%
type(num)
# Out:
# float

# %%
com=1+2j
type(com)
# Out:
# complex

# %%
num2=int(12.345)

# %%
type(num2)
# Out:
# int

# %%
a=7
b=7.7

# %%
c=a+b
print(c)
# Out:
# 14.7

# %%
type(c)
# Out:
# float

# %%
mod=a%b
print(mod)
# Out:
# 7.0

# %%
d=3 ** 2.4
print(d)
# Out:
# 13.966610165238235

# %%
q= 6 //2
print(q)
# Out:
# 3

# %%
float(q)
# Out:
# 3.0

# %%
import math
math.comb(3,6)
# Out:
# 0

# %%
math.comb(6,3)
# Out:
# 20

# %%
math.dist([1,2,3],[4,5,6]  )
# Out:
# 5.196152422706632

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.gcd(12, 15)
# Out:
# 3

# %%
round(math.pi,3)
# Out:
# 3.142
