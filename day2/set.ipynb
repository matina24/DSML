# %%
setA={1, 2, 3, 4, 5}
type(setA)
# Out:
# set

# %%
setA
# Out:
# {1, 2, 3, 4, 5}

# %%
set(["mississipi", "lossantos", "missouri"])
# Out:
# {'lossantos', 'mississipi', 'missouri'}

# %%
set("mississipi")
# Out:
# {'i', 'm', 'p', 's'}

# %%
setA.add(6)
setA
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
setA.update({7, 8, 9})
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
setA.add("class")
setA
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 'class'}

# %%
setA.pop()
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9, 'class'}

# %%
setA.remove("class")
setA
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
setA.discard(5)
setA
# Out:
# {2, 3, 4, 6, 7, 8, 9}

# %%
a={1, 2, 3, 4, 5}
b={4, 5, 6, 7, 8}
aUb=a.union(b)
aUb
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
aNb=a.intersection(b)
aNb
# Out:
# {4, 5}

# %%
b_a=b.difference(a)
b_a
# Out:
# {6, 7, 8}

# %%
a.intersection_update(b)
a
# Out:
# {4, 5}

# %%
a.symmetric_difference(b)
# Out:
# {6, 7, 8}

# %%
a
# Out:
# {4, 5}

# %%
b
# Out:
# {4, 5, 6, 7, 8}

# %%
a.issubset(b)
# Out:
# True

# %%
a.issuperset(b)
# Out:
# False

# %%
a<b
# Out:
# True

# %%
b.isdisjoint(a)
# Out:
# False
