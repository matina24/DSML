# %%
squared=[]
for i in range(1,11):
    if i%2==0:
        squared.append(i**2)
print(squared)
# Out:
# [4, 16, 36, 64, 100]

# %%
squared=[i**2 for i in range(1,11) if i%2==0]
squared
# Out:
# [4, 16, 36, 64, 100]

# %%
adjective = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

# for a in adjective:
#     for f in fruits:
#         print(a, f)

pair = [f"{a} {f}" for a in adjective for f in fruits]
pair
# Out:
# ['red apple',
#  'red banana',
#  'red cherry',
#  'big apple',
#  'big banana',
#  'big cherry',
#  'tasty apple',
#  'tasty banana',
#  'tasty cherry']

# %%
squared={i:i**2 for i in range(1,11) if i%2==0}
squared
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
sent = "Although she was extremely tired after working a long shift at the local hospital, Maria still managed to stop by the grocery store, pick up fresh vegetables for dinner, and help her younger brother with his math homework."
result = {word: len(word) for word in sent.split() if len(word) > 4}

print(result)
# Out:
# {'Although': 8, 'extremely': 9, 'tired': 5, 'after': 5, 'working': 7, 'shift': 5, 'local': 5, 'hospital,': 9, 'Maria': 5, 'still': 5, 'managed': 7, 'grocery': 7, 'store,': 6, 'fresh': 5, 'vegetables': 10, 'dinner,': 7, 'younger': 7, 'brother': 7, 'homework.': 9}

# %%
squared={i**2 for i in range(1,11) if i%2==0}
squared
# Out:
# {4, 16, 36, 64, 100}

# %%
chars=["c", "a", "t"]
pairs={char1+char2 for char1 in chars for char2 in chars}
pairs
# Out:
# {'aa', 'ac', 'at', 'ca', 'cc', 'ct', 'ta', 'tc', 'tt'}

# %%
raw_data=['150', 'invalid', '80','204','999','STOP','300','450']
numbers = [int(x) for x in raw_data if x.isdigit()]
real_load=[x for x in numbers if x<999 and x>100]

print(real_load)
# Out:
# [150, 204, 300, 450]
