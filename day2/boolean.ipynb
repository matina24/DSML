# %%
flag= True

# %%
type(flag)
# Out:
# bool

# %%
c=5>6
c
# Out:
# False

# %%
(1<5) and (5>6)
# Out:
# False

# %%
(1<5) or (5>6)
# Out:
# True

# %%
not(1<5)
# Out:
# False

# %%
bool(9)
# Out:
# True

# %%
bool("a")
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("")
# Out:
# False
