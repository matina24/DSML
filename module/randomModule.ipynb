# %%
import random
random.random()
# Out:
# 0.5629176328916724

# %%
random.uniform(10,15)
# Out:
# 12.385553855562028

# %%
random.randint(10,20)
# Out:
# 13

# %%
random.randrange(10,40,2)
# Out:
# 16

# %%
random.randrange(11,41,2)
# Out:
# 29

# %%
cards =["nine", "ten", "jack", "queen", "king", "ace"]
random.shuffle(cards)
cards
# Out:
# ['ten', 'queen', 'king', 'nine', 'jack', 'ace']

# %%
random.choice(cards)
# Out:
# 'ace'

# %%
random.choices(cards, k = 3)
# Out:
# ['queen', 'ten', 'king']

# %%
random.sample(cards, k=3)
# Out:
# ['ace', 'king', 'queen']

# %%
random.normalvariate(mu=5, sigma=2.3)
# Out:
# 6.372243990575281

# %%
random.expovariate(7)
# Out:
# 0.063712581963307

# %%
# random.seed(456)
random.random()
# Out:
# 0.4352093219057409

# %%
random.randint(1,100)
# Out:
# 83
