# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.mkdir("test")

# %%
os.chdir("test")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\lenovo\\OneDrive\\Desktop\\skillshikshya\\DSML\\test'
