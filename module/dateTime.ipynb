# %%
import datetime

# %%
birth_date= datetime.date(2001,8,5)

# %%
today= datetime.date.today()

# %%
age= today - birth_date
age
# Out:
# datetime.timedelta(days=9143)

# %%
age.days/ 365
# Out:
# 25.04931506849315

# %%
today.strftime(" %a - %d %b, %Y")
# Out:
# ' Tue - 18 Aug, 2026'

# %%
dt = datetime.datetime(2025, 12, 3, 8, 29, 55)
dt
# Out:
# datetime.datetime(2025, 12, 3, 8, 29, 55)

# %%
dt.hour
# Out:
# 8

# %%
today = datetime.datetime.now()
today
# Out:
# datetime.datetime(2026, 8, 18, 7, 17, 16, 48431)

# %%
datetime.datetime.fromtimestamp(1786935886)
# Out:
# datetime.datetime(2026, 8, 17, 8, 49, 46)

# %%
today - dt
# Out:
# datetime.timedelta(days=257, seconds=82041, microseconds=48431)

# %%
year_5 = datetime.timedelta(days= 5 * 365)
today + year_5
# Out:
# datetime.datetime(2031, 8, 17, 7, 17, 16, 48431)

# %%
NST= datetime.timezone(datetime.timedelta( hours= 5, minutes= 45))
print(NST)
# Out:
# UTC+05:45

# %% [markdown]
# TIME

# %%
import time

# %%
time.time()
# Out:
# 1787017207.4317794

# %%
time.ctime()
# Out:
# 'Tue Aug 18 07:28:51 2026'

# %%
time.gmtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=1, tm_min=44, tm_sec=15, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2026, tm_mon=8, tm_mday=18, tm_hour=7, tm_min=29, tm_sec=26, tm_wday=1, tm_yday=230, tm_isdst=0)

# %%
#sleep
print("loading ...")
time.sleep(5)
print("completed")
# Out:
# loading ...
# completed

# %%
start= time.time()

print("Function Started")
time.sleep(3)
print("function ended")

end= time.time()
# Out:
# Function Started
# function ended

# %%
end- start
# Out:
# 3.0011188983917236
